# %% [markdown]
# <a href="https://www.kaggle.com/code/gncgulce/telco-churn-prediction-eda-ml?scriptVersionId=188405127" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style='background-color: #f4a460; padding: 10px'>
#
# <h1> Business Problem</h1>
#
# A machine learning model is expected to be developed to predict customers who will leave the company.
#
# </div>
#
# ![Churn.jpg](attachment:af594d6c-18bb-4ece-a1f2-3e9d18e91c33.jpg)
#
# <div style='background-color: #f4a460; padding: 10px'>
#
# <h1> Dataset</h1>
#
# The Telco customer churn dataset contains information about a fictional telecommunications company that provided home phone and Internet services to 7043 customers in California during the third quarter. It shows which customers have left, stayed, or signed up for their services.
# <blockquote><strong><h1>Details</h1></strong></blockquote>
# <strong>21 Variables | 7043 Observations</strong>
#
# </div>
#
# <table style="width:100%; border: 1px solid #ddd; border-collapse: collapse;">
#   <colgroup>
#     <col style="width: 18%;">
#     <col style="width: 70%;">
#   </colgroup>
#   <tr style="background-color: #f4a460;">
#     <th style="border: 1px solid #ddd; font-size: 13px; padding: 8px; text-align: left;">Variable</th>
#     <th style="border: 1px solid #ddd; font-size: 13px; padding: 8px; text-align: left;">Description</th>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">CustomerId</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Customer ID</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">Gender</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Gender</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">SeniorCitizen</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer is a senior citizen (1, 0)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">Partner</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer has a partner (Yes, No)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">Dependents</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer has dependents (Yes, No)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">Tenure</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Number of months the customer has stayed with the company</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">PhoneService</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer has phone service (Yes, No)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">MultipleLines</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer has multiple lines (Yes, No, No phone service)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">InternetService</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Customer’s internet service provider (DSL, Fiber optic, No)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">OnlineSecurity</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer has online security (Yes, No, No internet service)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">OnlineBackup</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer has online backup (Yes, No, No internet service)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">DeviceProtection</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer has device protection (Yes, No, No internet service)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">TechSupport</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer has tech support (Yes, No, No internet service)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">StreamingTV</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer has streaming TV (Yes, No, No internet service)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">StreamingMovies</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer has streaming movies (Yes, No, No internet service)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">Contract</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Customer’s contract term (Month-to-month, One year, Two year)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">PaperlessBilling</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer has paperless billing (Yes, No)</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">PaymentMethod</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Customer’s payment method (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic))</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">MonthlyCharges</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">The amount charged to the customer monthly</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">TotalCharges</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">The total amount charged to the customer</td>
#   </tr>
#   <tr style="background-color: #ffe4b5;">
#     <td style="border: 1px solid #ddd; padding: 8px;">Churn</td>
#     <td style="border: 1px solid #ddd; background-color: #fdf5e6; padding: 8px;">Whether the customer churned (Yes or No)</td>
#   </tr>
# </table>

# %% [markdown]
# <div style='background-color: #fdf5e6; padding: 10px'>
#
# Before developing the model, we will perform the necessary data analysis and feature engineering steps.
#
# Let's start !
#
# </div>

# %% [markdown]
# <div style='background-color: #f4a460; padding: 10px;'>
#
# <h1> Importing Necessary Libraries and Settings</h1>
# </div>

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import scipy.stats as stats
from matplotlib.pyplot import plot
from matplotlib.colors import LinearSegmentedColormap
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder,StandardScaler, OneHotEncoder
from sklearn.model_selection import GridSearchCV, cross_validate, train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 170)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# <div style='background-color: #f4a460; padding: 10px;'>
#
# <h1>Reading the Dataset</h1>
# </div>

# %%
telco = pd.read_csv('/kaggle/input/telco-churn/telco_churn.csv')
df = telco.copy() # Creating a copy of the dataset for ease of use
df.head(3)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No  No phone service             DSL             No          Yes               No          No
# 1  5575-GNVDE    Male              0      No         No      34          Yes                No             DSL            Yes           No              Yes          No
# 2  3668-QPYBK    Male              0      No         No       2          Yes                No             DSL            Yes          Yes               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling     PaymentMethod  MonthlyCharges TotalCharges Churn
# 0          No              No  Month-to-month              Yes  Electronic check          29.850        29.85    No
# ...

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Quick overview of the dataset.</li>
#     </ul>
# </div>

# %%
def check_detail(dataframe):
    d = {'SHAPE': dataframe.shape,
        'COLUMNS': dataframe.columns,
        'INDEX': dataframe.index,
        'VALUE TYPES': dataframe.dtypes,
        'DUPLICATED VALUES': dataframe.duplicated().sum(),
        'NUMBER OF UNIQUE VALUES': dataframe.nunique(),
        'ANY MISSING VALUES': dataframe.isnull().values.any(),
        'MISSING VALUES': dataframe.isnull().sum(),
        'DESCRIBE.T': dataframe.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T}
    hashtags = '---------------------------'
    for key, val in d.items():
        print(f'{hashtags} {key} {hashtags}')
        print(val)
    print(f'{hashtags} {"LIST END"} {hashtags}')
   

check_detail(dataframe=df)
# Out:
# --------------------------- SHAPE ---------------------------
# (7043, 21)
# --------------------------- COLUMNS ---------------------------
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')
# --------------------------- INDEX ---------------------------
# RangeIndex(start=0, stop=7043, step=1)
# --------------------------- VALUE TYPES ---------------------------
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# ...

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Fixing the variables names ( 'tenure' , 'gender' )</li>
#     </ul>
# </div>

# %%
df.rename(columns={'tenure': 'Tenure', 'gender': 'Gender'}, inplace=True)
df.head(3)
# Out:
#    customerID  Gender  SeniorCitizen Partner Dependents  Tenure PhoneService     MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No  No phone service             DSL             No          Yes               No          No
# 1  5575-GNVDE    Male              0      No         No      34          Yes                No             DSL            Yes           No              Yes          No
# 2  3668-QPYBK    Male              0      No         No       2          Yes                No             DSL            Yes          Yes               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling     PaymentMethod  MonthlyCharges TotalCharges Churn
# 0          No              No  Month-to-month              Yes  Electronic check          29.850        29.85    No
# ...

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>TotalCharges should be a numeric variable and the Churn variable should be binary encoded or have its class assignment.</li>
#         <li>I prefer to class assignment as Yes = 1, No = 0 for the Churn variable.</li>
#         <li>This way, the type of the Churn variable will be converted to integer.</li>
#     </ul>
# </div>

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['Churn'] = df['Churn'].apply(lambda x : 1 if x == 'Yes' else 0)
print(df['TotalCharges'].dtype , df['Churn'].dtype)
# Out:
# float64 int64

# %% [markdown]
# <div style='background-color: #f4a460; padding: 10px;'>
#     <h1>Detailed EDA</h1>
# </div>
#
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote><strong>CAPTURE OF CATEGORICAL AND NUMERICAL VARIABLES</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px;'>
#     <ul>
#         <li>This function identifies the names of categorical, numerical, and categorical but cardinal variables in the dataset.</li>
#         <li><strong>Note:</strong> Numeric-looking categorical variables are also included in categorical variables.</li>
#     </ul>
# </div>

# %%
def grab_col_names(dataframe, cat_th=10, car_th=20):
    cat_cols = [col for col in dataframe.columns if dataframe[col].dtype == 'O']  # Categorical columns
    num_but_cat = [col for col in dataframe.columns if
                   dataframe[col].nunique() < cat_th and dataframe[col].dtype != 'O']  # Numeric but categorical
    cat_but_car = [col for col in dataframe.columns if
                   dataframe[col].nunique() > car_th and dataframe[col].dtype == 'O']  # Categorical but cardinal
    cat_cols += num_but_cat  # Combine categorical columns
    cat_cols = [col for col in cat_cols if col not in cat_but_car]  # Exclude cardinal columns from categorical columns

    num_cols = [col for col in dataframe.columns if dataframe[col].dtype != 'O']  # Numerical columns
    num_cols = [col for col in num_cols if col not in num_but_cat]  # Exclude numeric-looking categories

    print(f'Observations: {dataframe.shape[0]}')
    print(f'Variables: {dataframe.shape[1]}')
    print(f'cat_cols: {len(cat_cols)}')
    print(f'num_cols: {len(num_cols)}')
    print(f'cat_but_car: {len(cat_but_car)}')
    print(f'num_but_cat: {len(num_but_cat)}')

    return cat_cols, num_cols, cat_but_car

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Identify and separate variable types.</li>
#     </ul>
# </div>

# %%
def identify_check(dataframe):
    print('-' * 80)
    print(f'Categorical : {cat_cols}')
    print('-' * 80)
    print(f'Numerical : {num_cols}')
    print('-' * 80)
    print(f'Categorical but Cardinal : {cat_but_car}')

cat_cols, num_cols, cat_but_car = grab_col_names(df)
identify_check(df)
# Out:
# Observations: 7043
# Variables: 21
# cat_cols: 17
# num_cols: 3
# cat_but_car: 1
# num_but_cat: 2
# --------------------------------------------------------------------------------
# Categorical : ['Gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'SeniorCitizen', 'Churn']
# --------------------------------------------------------------------------------
# Numerical : ['Tenure', 'MonthlyCharges', 'TotalCharges']
# --------------------------------------------------------------------------------
# Categorical but Cardinal : ['customerID']

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote><strong>CATEGORICAL VARIABLES ANALYSIS</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Function to summarize and optionally plot categorical variables.</li>
#     </ul>
# </div>

# %%
def to_analysis_cat(dataframe, c_cols, ratio=False, plot=False):
    print('-' * 80)
    if dataframe[c_cols].dtype == 'bool':
        dataframe[c_cols] = dataframe[c_cols].astype(int)

    if ratio:
        print(pd.DataFrame({c_cols: dataframe[c_cols].value_counts(),
                            'Ratio (%)': 100 * dataframe[c_cols].value_counts() / len(dataframe)}))
    print('-' * 80)
    if plot:
        values = dataframe[c_cols].value_counts()
        fig, axes = plt.subplots(1, len(values), figsize=(len(values) * 8, 9))

        for i, (index, value) in enumerate(values.items()):
            ax = axes[i]
            ax.pie([value, len(dataframe) - value], labels=[f'{index} ({value})', f'Others ({len(dataframe) - value})'],
                   colors=['#cd853f', '#eee9bf', '#fffacd'], autopct='%1.1f%%', startangle=90)
            ax.set_title(f'{c_cols} - {index}')
            ax.axis('equal') 

        plt.suptitle(f'RATIO by {c_cols}', y=1.05, fontsize=20)
        plt.tight_layout()
        plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   Tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Loop through categorical columns to summarize them.</li>
#     </ul>
# </div>

# %%
for col in cat_cols:
    to_analysis_cat(df, col, ratio=True, plot=True)
# Out:
# --------------------------------------------------------------------------------
#         Gender  Ratio (%)
# Gender
# Male      3555     50.476
# Female    3488     49.524
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#          Partner  Ratio (%)
# Partner
# No          3641     51.697
# Yes         3402     48.303
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#             Dependents  Ratio (%)
# Dependents
# No                4933     70.041
# Yes               2110     29.959
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#               PhoneService  Ratio (%)
# PhoneService
# Yes                   6361     90.317
# ...

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote><strong>NUMERICAL VARIABLES ANALYSIS</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Function to summarize and optionally plot numerical variables.</li>
#     </ul>
# </div>

# %%
def to_analysis_num(dataframe,n_cols,T=False, plot=False):
    if T:
        print('-' * 80)
        quantiles = [0.05, 0.25, 0.50, 0.75, 0.95, 0.99]
        print(dataframe[n_cols].describe(quantiles).T)

    if plot:
        [(dataframe[n_cols].hist(figsize=(5, 6) ,bins=30,
                                 density=True,label=n_cols, 
                                 alpha=0.8, color='#f4a460'),
          plt.title(f'Distribution of {n_cols} Variable'),
          plt.xlabel(n_cols), plt.ylabel('Frequency'), plt.legend(loc='upper right')),
          plt.show(block=True)]

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Loop through numerical columns to summarize and plot them.</li>
#     </ul>
# </div>

# %%
for col in num_cols:
    to_analysis_num(df, col, T=True, plot=True)
# Out:
# --------------------------------------------------------------------------------
# count   7043.000
# mean      32.371
# std       24.559
# min        0.000
# 5%         1.000
# 25%        9.000
# 50%       29.000
# 75%       55.000
# 95%       72.000
# 99%       72.000
# max       72.000
# Name: Tenure, dtype: float64
# --------------------------------------------------------------------------------
# count   7043.000
# mean      64.762
# std       30.090
# min       18.250
# 5%        19.650
# 25%       35.500
# 50%       70.350
# 75%       89.850
# 95%      107.400
# 99%      114.729
# max      118.750
# Name: MonthlyCharges, dtype: float64
# --------------------------------------------------------------------------------
# count   7032.000
# mean    2283.300
# std     2266.771
# min       18.800
# 5%        49.605
# 25%      401.450
# 50%     1397.475
# 75%     3794.738
# 95%     6923.590
# 99%     8039.883
# max     8684.800
# Name: TotalCharges, dtype: float64

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote><strong>TARGET VARIABLES ANALYSIS</strong></blockquote>
# </div>
#
# <div style='background-color: #ffe4b5; padding: 10px;'>
#     <blockquote><strong>Analysis of Categorical Variables by Target</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Function to compare the means, ratio, count of categorical variables by the target variable.</li>
#     </ul>
# </div>

# %%
def cat_by_target(dataframe, target, c_cols, plot=False):
    
    cat_tar = pd.DataFrame({'Target Mean': dataframe.groupby(c_cols)[target].mean(), 
                            'Count': dataframe[c_cols].value_counts(), 
                            'Ratio (%)': 100 * dataframe[c_cols].value_counts() / len(dataframe)})
    
    print('-' * 80)
    print(c_cols)
    print('-' * 80)
    print(cat_tar, end='\n\n\n')
    
    if plot:
        colors = ['#f4a460', '#eee8aa', '#ffe4b5', '#ffefd5']
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
        
        # Hedef Değişken Ortalaması için Bar Plot
        values = dataframe[c_cols].value_counts()
        sns.barplot(x=cat_tar.index, y=cat_tar['Target Mean'],palette=colors[:len(cat_tar)], ax=ax1)
        ax1.set_title(f'Target Mean by {c_cols}')
        ax1.set_ylabel('Target Mean')
        ax1.tick_params(axis='x', rotation=30)
        
        # Kategorik Değişken Dağılımı için Pie Chart
        ax2.pie(x=cat_tar['Count'], labels=cat_tar.index, autopct='%1.1f%%', startangle=90, colors=colors[:len(values)])
        ax2.set_title(f'Ratio by {c_cols}')
        ax2.legend(labels=[f'{index} - {row["Ratio (%)"]:.2f}%'for index, row in cat_tar.iterrows()],
                   loc='center left', bbox_to_anchor=(1, 0, 0.5, 1))
        
        plt.subplots_adjust(wspace=0.4, hspace=0.4)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To execute the function for each categorical column.</li>
#     </ul>
# </div>

# %%
for col in cat_cols:
    cat_by_target(df, 'Churn', col, plot=True)
# Out:
# --------------------------------------------------------------------------------
# Gender
# --------------------------------------------------------------------------------
#         Target Mean  Count  Ratio (%)
# Gender
# Female        0.269   3488     49.524
# Male          0.262   3555     50.476
# --------------------------------------------------------------------------------
# Partner
# --------------------------------------------------------------------------------
#          Target Mean  Count  Ratio (%)
# Partner
# No             0.330   3641     51.697
# Yes            0.197   3402     48.303
# --------------------------------------------------------------------------------
# Dependents
# --------------------------------------------------------------------------------
#             Target Mean  Count  Ratio (%)
# Dependents
# No                0.313   4933     70.041
# Yes               0.155   2110     29.959
# ...

# %% [markdown]
# <div style='background-color: #ffe4b5; padding: 10px;'>
#     <blockquote><strong>Analysis of Numerical Variables by Target</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Function to compare the means of numerical columns by the target variable.</li>
#     </ul>
# </div>

# %%
def num_by_target(dataframe, target, n_cols, plot=False):
    # Hedef değişken (target) bazında sayısal değişkenlerin ortalamasını yazdır
    print('-' * 40)
    print(dataframe.groupby(target).agg({n_cols: 'mean'}))
    print('-' * 40)
    if plot:
        palette=['#f4a460', '#ffefd5']
        plt.figure(figsize=(8, 6))
        sns.violinplot(x=target, y=n_cols, data=dataframe, palette=palette)
        plt.title(f'Distribution of {n_cols} by {target}')
        plt.xlabel(target)
        plt.ylabel(n_cols)
        plt.show()

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To execute the function for each numerical column.</li>
#     </ul>
# </div>

# %%
for col in num_cols:
    num_by_target(df,'Churn', col, plot=True)
# Out:
# ----------------------------------------
#        Tenure
# Churn
# 0      37.570
# 1      17.979
# ----------------------------------------
# ----------------------------------------
#        MonthlyCharges
# Churn
# 0              61.265
# 1              74.441
# ----------------------------------------
# ----------------------------------------
#        TotalCharges
# Churn
# 0          2555.344
# 1          1531.796
# ----------------------------------------

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote><strong>CORRELATION ANALYSIS</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Display the correlation matrix for numerical variables.</li>
#     </ul>
# </div>

# %%
def corr_by_num(dataframe, target, n_cols, plot=False):
    num_df = dataframe[n_cols]
    corr_matrix = num_df.corr()
    print('Corr-Matrix:', corr_matrix)
    print('-' * 80)

    corr_with_tar = num_df.corrwith(dataframe[target]).sort_values(ascending=False)
    print('Hedef Değişken ile Korelasyon:\n', corr_with_tar)

    
    highest_corr = corr_with_tar.drop(target).idxmax()
    highest_corr_value = corr_with_tar[highest_corr]
    print(f'En Yüksek Korelasyon: {highest_corr} ({highest_corr_value})')
    print('-' * 80)

    if plot:
        custom_cmap = LinearSegmentedColormap.from_list('custom', ['#eee8aa', '#f4a460'])
        plt.figure(figsize=[12, 8])
        sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap=custom_cmap,
                    linewidths=.5,linecolor='black', cbar_kws={'label': 'Scale'})
        plt.title('Correlation Matrix:', fontsize=20)
        plt.xticks(fontsize=7, rotation=40)
        plt.yticks(fontsize=7, rotation=0)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To analyze how each variable correlates with the target variable 'Churn'.</li>
#     </ul>
# </div>

# %%
num_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()  # Tüm sayısal kolonları seçme
corr_by_num(df, 'Churn', num_cols, plot=True)
# Out:
# Corr-Matrix:                 SeniorCitizen  Tenure  MonthlyCharges  TotalCharges  Churn
# SeniorCitizen           1.000   0.017           0.220         0.102  0.151
# Tenure                  0.017   1.000           0.248         0.826 -0.352
# MonthlyCharges          0.220   0.248           1.000         0.651  0.193
# TotalCharges            0.102   0.826           0.651         1.000 -0.199
# Churn                   0.151  -0.352           0.193        -0.199  1.000
# --------------------------------------------------------------------------------
# Hedef Değişken ile Korelasyon:
#  Churn             1.000
# MonthlyCharges    0.193
# SeniorCitizen     0.151
# TotalCharges     -0.199
# Tenure           -0.352
# dtype: float64
# En Yüksek Korelasyon: MonthlyCharges (0.19335642223784694)
# --------------------------------------------------------------------------------

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote><strong>MISSING VALUES ANALYSIS</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Function to create a summary table of missing values in the dataframe.</li>
#     </ul>
# </div>

# %%
def missing_values_table(dataframe, na_name=False):
    na_columns = [col for col in dataframe.columns if dataframe[col].isnull().sum() > 0]
    n_miss = dataframe[na_columns].isnull().sum().sort_values(ascending=False)
    ratio = (dataframe[na_columns].isnull().sum() / dataframe.shape[0] * 100).sort_values(ascending=False)
    missing_df = pd.concat([n_miss, np.round(ratio, 2)], axis=1, keys=['n_miss', 'ratio'])
    print(missing_df, end='\n')
    if na_name:
        return na_columns

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To execute the function to display the missing values table.</li>
#     </ul>
# </div>

# %%
na_columns = missing_values_table(df, na_name=True)
# Out:
#               n_miss  ratio
# TotalCharges      11  0.160

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>There are 11 missing values in the TotalCharges variable.</li>
#     </ul>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; line-height: 1.2;'>
#     <ul>
#         <li>To fill missing values in 'TotalCharges' with the median of the column.</li>
#     </ul>
# </div>

# %%
df['TotalCharges'].fillna(df['TotalCharges'].median(), inplace=True)

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To verify if missing values have been addressed.</li>
#     </ul>
# </div>

# %%
df.isnull().sum()
# Out:
# customerID          0
# Gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# Tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote><strong>OUTLIER ANALYSIS</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Function to calculate outlier thresholds</li>
#     </ul>
# </div>

# %%
def outlier_thresholds(dataframe, col_name, q1=0.05, q3=0.95):
    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Function to check for outliers in a column.</li>
#     </ul>
# </div>

# %%
def check_outlier(dataframe, col_name):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name)
    if dataframe[(dataframe[col_name] > up_limit) | (dataframe[col_name] < low_limit)].any(axis=None):
        return True
    else:
        return False

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To analyze outliers for numerical columns.</li>
#     </ul>
# </div>

# %%
for col in num_cols:
    print(col, check_outlier(df, col))
# Out:
# SeniorCitizen False
# Tenure False
# MonthlyCharges False
# TotalCharges False
# Churn False

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Our dataset doesn't contain any outliers.</li>
#     </ul>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; line-height: 1.2;'>
#     <ul>
#         <li>The 'customerID' column doesn't carry significant information, so I prefer to delete it.</li>
#     </ul>
# </div>

# %%
df.drop('customerID', axis = 1, inplace = True)
df.columns
# Out:
# Index(['Gender', 'SeniorCitizen', 'Partner', 'Dependents', 'Tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.shape # to check again.
# Out:
# (7043, 20)

# %% [markdown]
# <div style='background-color: #f4a460; padding: 10px;'>
#     <h1>Feature Engineering</h1>
# </div>
#
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote><strong>BASE MODEL</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px;'>
#     <ul>
#         <li>Make a copy of the original dataframe for model training to preserve the original data and exclude the target variable 'Churn' from the list of categorical columns.</li>
#     </ul>
# </div>

# %%
df_base = df.copy()
base_cat_cols = [col for col in cat_cols if col not in ["Churn"]]

# %%
y = df_base['Churn']
X = df_base.drop(['Churn'], axis=1)

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Identify categorical and numerical variables.</li>
#     </ul>
# </div>

# %%
cat_cols_list = X.select_dtypes(include=['object']).columns
num_cols_list = X.select_dtypes(include=['int64', 'float64']).columns

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Creating preprocessing pipeline of One-Hot Encoding & Standard Scaler for the model I'll apply.</li>
#     </ul>
# </div>

# %%
prep = ColumnTransformer(transformers=[('num', StandardScaler(), num_cols_list),('cat', OneHotEncoder(), cat_cols_list)])

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To include the model in the pipeline.</li>
#     </ul>
# </div>

# %%
line = Pipeline(steps=[('preprocessor', prep),
                           ('classifier', LogisticRegression())])

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Evaluate the Model with 10-Fold Cross-Validation.</li>
#     </ul>
# </div>

# %%
cv_results = cross_validate(line, X, y, cv=10, scoring=['accuracy', 'f1', 'roc_auc', 'precision', 'recall'])

# %% [markdown]
# <div style='background-color: #ffe4b5; padding: 10px;'>
#     <blockquote><strong>Base Model Setup</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Target variable 'Churn' consists of two categories: "Yes" and "No". This makes it a binary classification problem and Logistic Regression is a model designed for binary classification problems. Additionally, Logistic Regression estimates the probability of the dependent variable belonging to a specific class. This makes it particularly suitable for modeling the likelihood of an event like customer churn. Therefore, I'm choosing Logistic Regression as the base model.</li>
#         <li>Using Hold-Out Method & Cross Validation</li>
#     </ul>
# </div>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=34) # to split

line.fit(X_train, y_train) # to fit

y_pred = line.predict(X_test) # predictions

print(f"{'-' * 10} Base Model  {'-' * 10}")
print(f"Accuracy: {round(cv_results['test_accuracy'].mean(), 4)}")
print(f"Recall: {round(cv_results['test_recall'].mean(), 4)}")
print(f"Precision: {round(cv_results['test_precision'].mean(), 4)}")
print(f"F1: {round(cv_results['test_f1'].mean(), 4)}")
print(f"Roc_Auc: {round(cv_results['test_roc_auc'].mean(), 4)}")
# Out:
# ---------- Base Model  ----------
# Accuracy: 0.8043
# Recall: 0.5506
# Precision: 0.6566
# F1: 0.5987
# Roc_Auc: 0.8453

# %% [markdown]
# <div style='background-color: #cd853f; padding: 10px;'>
#     <blockquote><strong>Comment</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>These results summarize the model's performance in predicting customer churn. The accuracy is around 80%, but the precision and F1 score are lower, indicating challenges in predicting customer churn.</li>
#         <li>After feature engineering steps, I'll compare the base model with other models and aim to improve performance through hyperparameter analysis.</li>
#     </ul>
# </div>

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote><strong>FEATURE EXTRACTION</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To create new features with columns.</li>
#     </ul>
# </div>

# %%
cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations: 7043
# Variables: 20
# cat_cols: 17
# num_cols: 3
# cat_but_car: 0
# num_but_cat: 2

# %%
# 1) Creating a categorical variable based on 'Tenure'
# This categorizes the `tenure` values into year ranges.
df.loc[(df['Tenure'] >= 0) & (df['Tenure'] <= 12), 'NEW_TENURE_YEAR'] = '0-1 Year'
df.loc[(df['Tenure'] > 12) & (df['Tenure'] <= 24), 'NEW_TENURE_YEAR'] = '1-2 Year'
df.loc[(df['Tenure'] > 24) & (df['Tenure'] <= 36), 'NEW_TENURE_YEAR'] = '2-3 Year'
df.loc[(df['Tenure'] > 36) & (df['Tenure'] <= 48), 'NEW_TENURE_YEAR'] = '3-4 Year'
df.loc[(df['Tenure'] > 48) & (df['Tenure'] <= 60), 'NEW_TENURE_YEAR'] = '4-5 Year'
df.loc[(df['Tenure'] > 60) & (df['Tenure'] <= 72), 'NEW_TENURE_YEAR'] = '5-6 Year'

# 2) Labeling engaged customers
# Customers with a contract of one or two years are considered engaged.
df['NEW_Engaged'] = df['Contract'].apply(lambda x: 1 if x in ['One year', 'Two year'] else 0)

# 3) Identifying customers without any protection services
# Customers who do not have online backup, device protection, or tech support.
df['NEW_noProt'] = df.apply(lambda x: 1 if (x['OnlineBackup'] != 'Yes') or (x['DeviceProtection'] != 'Yes') or (x['TechSupport'] != 'Yes') else 0, axis=1)

# 4) Young customers with a monthly contract
# Identifying customers who are not engaged (monthly contract) and not senior citizens.
df['NEW_Young_Not_Engaged'] = df.apply(lambda x: 1 if (x['NEW_Engaged'] == 0) and (x['SeniorCitizen'] == 0) else 0, axis=1)

# 5) Total number of services subscribed to by the customer
# Counting the number of services where the customer has a "Yes" response.
df['NEW_TotalServices'] = (df[['PhoneService', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']] == 'Yes').sum(axis=1)

# 6) Customers with any streaming services
# Identifying customers who have either streaming TV or streaming movies.
df['NEW_FLAG_ANY_STREAMING'] = df.apply(lambda x: 1 if (x['StreamingTV'] == 'Yes') or (x['StreamingMovies'] == 'Yes') else 0, axis=1)

# 7) Automatic payment flag
# Identifying customers who use automatic payment methods (bank transfer or credit card).
df['NEW_FLAG_AutoPayment'] = df['PaymentMethod'].apply(lambda x: 1 if x in ['Bank transfer (automatic)', 'Credit card (automatic)'] else 0)

# 8) Average monthly charges
# Calculating the average monthly charges by dividing the total charges by the tenure plus one.
df['NEW_AVG_Charges'] = df['TotalCharges'] / (df['Tenure'] + 1)

# 9) Increase in current price compared to the average price
# The ratio of average charges to the current monthly charges.
df['NEW_Increase'] = df['NEW_AVG_Charges'] / df['MonthlyCharges']

# 10) Average service fee
# Calculating the average fee per service by dividing the monthly charges by the total number of services plus one.
df['NEW_AVG_Service_Fee'] = df['MonthlyCharges'] / (df['NEW_TotalServices'] + 1)

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>The variables we created are reflected in the dataset.</li>
#     </ul>
# </div>

# %%
df.shape #to check
# Out:
# (7043, 30)

# %%
df.head(3) # to check again
# Out:
#    Gender  SeniorCitizen Partner Dependents  Tenure PhoneService     MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0  Female              0     Yes         No       1           No  No phone service             DSL             No          Yes               No          No          No
# 1    Male              0      No         No      34          Yes                No             DSL            Yes           No              Yes          No          No
# 2    Male              0      No         No       2          Yes                No             DSL            Yes          Yes               No          No          No
#
#   StreamingMovies        Contract PaperlessBilling     PaymentMethod  MonthlyCharges  TotalCharges  Churn NEW_TENURE_YEAR  NEW_Engaged  NEW_noProt  \
# 0              No  Month-to-month              Yes  Electronic check          29.850        29.850      0        0-1 Year            0           1
# ...

# %%
cat_cols, num_cols, cat_but_car = grab_col_names(df)
identify_check(df)
# Out:
# Observations: 7043
# Variables: 30
# cat_cols: 24
# num_cols: 6
# cat_but_car: 0
# num_but_cat: 8
# --------------------------------------------------------------------------------
# Categorical : ['Gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'NEW_TENURE_YEAR', 'SeniorCitizen', 'Churn', 'NEW_Engaged', 'NEW_noProt', 'NEW_Young_Not_Engaged', 'NEW_TotalServices', 'NEW_FLAG_ANY_STREAMING', 'NEW_FLAG_AutoPayment']
# --------------------------------------------------------------------------------
# Numerical : ['Tenure', 'MonthlyCharges', 'TotalCharges', 'NEW_AVG_Charges', 'NEW_Increase', 'NEW_AVG_Service_Fee']
# --------------------------------------------------------------------------------
# Categorical but Cardinal : []

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To check correlation for all numerical columns.</li>
#     </ul>
# </div>

# %%
num_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist() 
corr_by_num(df, 'Churn', num_cols, plot=True)
# Out:
# Corr-Matrix:                         SeniorCitizen  Tenure  MonthlyCharges  TotalCharges  Churn  NEW_Engaged  NEW_noProt  NEW_Young_Not_Engaged  NEW_TotalServices  \
# SeniorCitizen                   1.000   0.017           0.220         0.103  0.151       -0.138       0.011                 -0.386              0.069
# Tenure                          0.017   1.000           0.248         0.825 -0.352        0.646      -0.357                 -0.561              0.497
# MonthlyCharges                  0.220   0.248           1.000         0.651  0.193       -0.060      -0.293                 -0.048              0.766
# TotalCharges                    0.103   0.825           0.651         1.000 -0.199        0.446      -0.462                 -0.415              0.765
# Churn                           0.151  -0.352           0.193        -0.199  1.000       -0.405       0.136                  0.259             -0.086
# ...

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Duplicate values occurred in the dataset (22). I prefer to delete them.</li>
#     </ul>
# </div>

# %%
check_detail(df)
# Out:
# --------------------------- SHAPE ---------------------------
# (7043, 30)
# --------------------------- COLUMNS ---------------------------
# Index(['Gender', 'SeniorCitizen', 'Partner', 'Dependents', 'Tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'NEW_TENURE_YEAR', 'NEW_Engaged', 'NEW_noProt', 'NEW_Young_Not_Engaged', 'NEW_TotalServices', 'NEW_FLAG_ANY_STREAMING', 'NEW_FLAG_AutoPayment', 'NEW_AVG_Charges',
#        'NEW_Increase', 'NEW_AVG_Service_Fee'],
#       dtype='object')
# --------------------------- INDEX ---------------------------
# RangeIndex(start=0, stop=7043, step=1)
# --------------------------- VALUE TYPES ---------------------------
# Gender                     object
# SeniorCitizen               int64
# Partner                    object
# ...

# %%
duplicated_rows = df[df.duplicated()]
print(duplicated_rows)

df = df.drop_duplicates()
# Out:
#       Gender  SeniorCitizen Partner Dependents  Tenure PhoneService MultipleLines InternetService       OnlineSecurity         OnlineBackup     DeviceProtection  \
# 964     Male              0      No         No       1          Yes            No             DSL                   No                   No                   No
# 1338    Male              0      No         No       1          Yes            No              No  No internet service  No internet service  No internet service
# 1491  Female              0      No         No       1          Yes            No              No  No internet service  No internet service  No internet service
# 1739    Male              0      No         No       1          Yes            No     Fiber optic                   No                   No                   No
# 1932    Male              0      No         No       1          Yes            No              No  No internet service  No internet service  No internet service
# ...

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To check again Outliers after Feature Extraction.</li>
#     </ul>
# </div>

# %%
for col in num_cols:
    print(f"{col}: {check_outlier(df, col)}")
# Out:
# SeniorCitizen: False
# Tenure: False
# MonthlyCharges: False
# TotalCharges: False
# Churn: False
# NEW_Engaged: False
# NEW_noProt: False
# NEW_Young_Not_Engaged: False
# NEW_TotalServices: False
# NEW_FLAG_ANY_STREAMING: False
# NEW_FLAG_AutoPayment: False
# NEW_AVG_Charges: True
# NEW_Increase: True
# NEW_AVG_Service_Fee: False

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Function to replace outliers with the thresholds.</li>
#     </ul>
# </div>

# %%
def replace_with_thresholds(dataframe, variable):
    low_limit, up_limit = outlier_thresholds(dataframe, variable, q1=0.05, q3=0.95)
    dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
    dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit

# %% [markdown]
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To analyze and handle outliers for numerical columns.</li>
#     </ul>
# </div>

# %%
outlier_columns =['NEW_AVG_Charges', 'NEW_Increase']
for col in outlier_columns:
    replace_with_thresholds(df, col)

# %%
for col in outlier_columns:
    print(f"{col}: {check_outlier(df, col)}")
# Out:
# NEW_AVG_Charges: False
# NEW_Increase: False

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; color: black;display: inline-block; width: auto;'>
#    <blockquote><strong>ENCODING</strong></blockquote>
# </div>
#
# <div style='background-color: #ffe4b5; padding: 10px;'>
#    <blockquote><strong>Label Encoding</strong></blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Transforming binary categorical variables into a machine-readable format.</li>
#     </ul>
# </div>

# %%
cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations: 7021
# Variables: 30
# cat_cols: 24
# num_cols: 6
# cat_but_car: 0
# num_but_cat: 8

# %%
def label_encoder(dataframe, binary_col):
    labelencoder = LabelEncoder()
    dataframe[binary_col] = labelencoder.fit_transform(dataframe[binary_col])
    return dataframe

binary_cols = [col for col in df.columns if df[col].dtypes == 'O' and df[col].nunique() == 2]

for col in binary_cols:
    df = label_encoder(df, col)

# %%
df.head(3) #to check
# Out:
#    Gender  SeniorCitizen  Partner  Dependents  Tenure  PhoneService     MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0       0              0        1           0       1             0  No phone service             DSL             No          Yes               No          No
# 1       1              0        0           0      34             1                No             DSL            Yes           No              Yes          No
# 2       1              0        0           0       2             1                No             DSL            Yes          Yes               No          No
#
#   StreamingTV StreamingMovies        Contract  PaperlessBilling     PaymentMethod  MonthlyCharges  TotalCharges  Churn NEW_TENURE_YEAR  NEW_Engaged  NEW_noProt  \
# 0          No              No  Month-to-month                 1  Electronic check          29.850        29.850      0        0-1 Year            0           1
# ...

# %% [markdown]
# <div style='background-color: #ffe4b5; padding: 10px;'>
#     <blockquote>
#         <strong>One-Hot Encoding</strong>
#     </blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Transforming categorical variables with more than two categories into a machine-readable format.</li>
#     </ul>
# </div>

# %%
cat_cols = [col for col in cat_cols if col not in binary_cols and col not in ["Churn", "NEW_TotalServices"]]
cat_cols
# Out:
# ['MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaymentMethod',
#  'NEW_TENURE_YEAR',
#  'SeniorCitizen',
#  'NEW_Engaged',
#  'NEW_noProt',
#  'NEW_Young_Not_Engaged',
#  'NEW_FLAG_ANY_STREAMING',
#  'NEW_FLAG_AutoPayment']

# %%
def one_hot_encoder(dataframe, c_cols, drop_first=False):
    dataframe = pd.get_dummies(dataframe, columns=c_cols, drop_first=drop_first)
    return dataframe


df = one_hot_encoder(df, cat_cols, drop_first=True)

# %%
df.head() #to check
# Out:
#    Gender  Partner  Dependents  Tenure  PhoneService  PaperlessBilling  MonthlyCharges  TotalCharges  Churn  NEW_TotalServices  NEW_AVG_Charges  NEW_Increase  \
# 0       0        1           0       1             0                 1          29.850        29.850      0                  1           14.925         0.500
# 1       1        0           0      34             1                 0          56.950      1889.500      0                  3           53.986         0.948
# 2       1        0           0       2             1                 1          53.850       108.150      1                  3           36.050         0.669
# 3       1        0           0      45             0                 0          42.300      1840.750      0                  3           40.016         0.946
# 4       0        0           0       2             1                 1          70.700       151.650      1                  1           50.550         0.715
#
# ...

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote>
#         <strong>FEATURE SCALING</strong>
#     </blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To express the observation units (numerical columns) on the same scale.</li>
#     </ul>
# </div>

# %%
sscaler_cols = [col for col in num_cols if col not in ['Churn']]

scaler = StandardScaler()

df[sscaler_cols] = scaler.fit_transform(df[sscaler_cols])

# %%
df.head(3)
# Out:
#    Gender  Partner  Dependents  Tenure  PhoneService  PaperlessBilling  MonthlyCharges  TotalCharges  Churn  NEW_TotalServices  NEW_AVG_Charges  NEW_Increase  \
# 0       0        1           0  -1.283             0                 1          -1.164        -0.997      0                  1           -1.425        -2.635
# 1       1        0           0   0.062             1                 0          -0.263        -0.176      0                  3           -0.176         0.305
# 2       1        0           0  -1.242             1                 1          -0.366        -0.963      1                  3           -0.750        -1.522
#
#    NEW_AVG_Service_Fee  MultipleLines_No phone service  MultipleLines_Yes  InternetService_Fiber optic  InternetService_No  OnlineSecurity_No internet service  \
# 0               -0.312                            True              False                        False               False                               False
# ...

# %% [markdown]
# <div style='background-color: #f4a460; padding: 10px;'>
#     <h1>Modelling</h1>
# </div>
#
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote>
#         <strong>MODEL LIST</strong>
#     </blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To define the target variable 'y', features 'X' and list of models to train and which I want to compare.</li>
#         <li>To facilitate comparison, I'm setting the 'random_state' parameter to 34 for all of models.</li>
#     </ul>
# </div>

# %%
y = df['Churn']
X = df.drop(['Churn'], axis=1)
models = [('LR', LogisticRegression(random_state=34)),
          ('KNN', KNeighborsClassifier()),
          ('CART', DecisionTreeClassifier(random_state=34)),
          ('RF', RandomForestClassifier(random_state=34)),
          ('SVM', SVC(gamma='auto', random_state=34)),
          ('XGB', XGBClassifier(random_state=34)),
          ('CatBoost', CatBoostClassifier(verbose=False, random_state=34))]

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote>
#         <strong>CROSS-VALIDATION</strong>
#     </blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To train each model and assess its performance through Cross-Validation.</li>
#     </ul>
# </div>
#
# <div style='background-color: #ffe4b5; padding: 10px; color: black;'>
#     <blockquote>
#         <strong>Based on these results, the choice of which model to select can depend on various factors:</strong>
#         <ul>
#             <li>At this point, I'd like to provide some background information.</li>
#         </ul>
#     </blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li><strong>Accuracy:</strong> Measures the overall model performance. The model with the highest accuracy may be the best overall for your dataset.</li>
#         <li><strong>Roc AUC:</strong> An important metric that assesses the classification model's performance. A higher area under the ROC curve (AUC) indicates better classification ability.</li>
#         <li><strong>Recall:</strong> Measures the ability to correctly predict the positive class. It is crucial in situations where false negatives are costly.</li>
#         <li><strong>Precision:</strong> Measures the probability that instances predicted as positive are actually positive. It is important when false positives are costly.</li>
#         <li><strong>F1 Score:</strong> Balances recall and precision, providing a balanced performance metric.</li>
#     </ul>
# </div>

# %%
for name, model in models:
    cv_results = cross_validate(model, X, y, cv=10, scoring=['accuracy', 'f1', 'roc_auc', 'precision', 'recall'])
 
    print(f"{'-' * 10} Model {name} {'-' * 10}")
    print(f"Accuracy: {round(cv_results['test_accuracy'].mean(), 4)}")
    print(f"Recall: {round(cv_results['test_recall'].mean(), 4)}")
    print(f"Precision: {round(cv_results['test_precision'].mean(), 4)}")
    print(f"F1: {round(cv_results['test_f1'].mean(), 4)}")
    print(f"Roc_Auc: {round(cv_results['test_roc_auc'].mean(), 4)}")
# Out:
# ---------- Model LR ----------
# Accuracy: 0.8067
# Recall: 0.5353
# Precision: 0.6693
# F1: 0.5942
# Roc_Auc: 0.8499
# ---------- Model KNN ----------
# Accuracy: 0.7714
# Recall: 0.5197
# Precision: 0.5756
# F1: 0.5458
# Roc_Auc: 0.782
# ---------- Model CART ----------
# Accuracy: 0.7251
# Recall: 0.4922
# Precision: 0.4812
# F1: 0.4864
# Roc_Auc: 0.6509
# ---------- Model RF ----------
# Accuracy: 0.7915
# Recall: 0.489
# Precision: 0.6384
# F1: 0.5534
# Roc_Auc: 0.8268
# ---------- Model SVM ----------
# Accuracy: 0.7986
# Recall: 0.4653
# Precision: 0.6738
# F1: 0.5498
# Roc_Auc: 0.8113
# ---------- Model XGB ----------
# Accuracy: 0.7838
# Recall: 0.504
# Precision: 0.6115
# F1: 0.5523
# Roc_Auc: 0.8222
# ---------- Model CatBoost ----------
# Accuracy: 0.7949
# Recall: 0.5089
# Precision: 0.6422
# F1: 0.5676
# Roc_Auc: 0.8406

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote>
#         <strong>HYPERPARAMETER TUNING</strong>
#     </blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To express the observation units(numerical columns) on the same scale.</li>
#         <li>Let's observe by adjusting the hyperparameters for the two most prominent models.</li>
#     </ul>
# </div>

# %%
lr_params = {
    'C': [0.1, 1, 10],
    'penalty': ['l2'], 
    'solver': ['liblinear', 'saga']}

#  to find the best parameters with grid search with cross-validation
lr_model = LogisticRegression(random_state=34, max_iter=10000)
grid_search = GridSearchCV(lr_model, lr_params, cv=3, scoring='accuracy', n_jobs=-1, verbose=1).fit(X, y)

# result of best parameter 
print('Best Parameter:', grid_search.best_params_)
print('Best Score:', grid_search.best_score_)

# final model
lr_final_model = LogisticRegression(**grid_search.best_params_, random_state=34, max_iter=10000).fit(X, y)

cv_results = cross_validate(lr_final_model, X, y, cv=5, scoring=['accuracy', 'recall', 'precision', 'f1', 'roc_auc']) 
print(f"LR Accuracy: {cv_results['test_accuracy'].mean()}")
print(f"LR Recall: {cv_results['test_recall'].mean()}")
print(f"LR Precision: {cv_results['test_precision'].mean()}")
print(f"LR F1: {cv_results['test_f1'].mean()}")
print(f"LR ROC AUC: {cv_results['test_roc_auc'].mean()}")
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# Best Parameter: {'C': 0.1, 'penalty': 'l2', 'solver': 'saga'}
# Best Score: 0.8065806367600473
# LR Accuracy: 0.8065793715971653
# LR Recall: 0.5336521461901863
# LR Precision: 0.6687786597593526
# LR F1: 0.5935009994480305
# LR ROC AUC: 0.8496876697625307

# %% [markdown]
# <div style='background-color: #cd853f; padding: 10px;'>
#     <blockquote>
#         <strong>Comment</strong>
#     </blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <strong>Results for First Model</strong>
#     <div style="display: flex; flex-wrap: wrap;">
#         <div style="margin-right: 20px;"><strong>Accuracy:</strong> 0.8043</div>
#         <div style="margin-right: 20px;"><strong>Recall:</strong> 0.5506</div>
#         <div style="margin-right: 20px;"><strong>Precision:</strong> 0.6566</div>
#         <div style="margin-right: 20px;"><strong>F1:</strong> 0.5987</div>
#         <div style="margin-right: 20px;"><strong>Roc_Auc:</strong> 0.8453</div>
#     </div>
#     <div>
#         <ul>
#             <li><strong>Accuracy and ROC AUC:</strong> Slight improvement, overall performance increased slightly.</li>
#             <li><strong>Recall:</strong> Decreased, performance in identifying churned customers dropped.</li>
#             <li><strong>Precision:</strong> Increased, accuracy among predicted churned customers rose.</li>
#             <li><strong>F1 Score:</strong> Slight decrease, due to the drop in recall.</li>
#         </ul>
#     </div>
# </div>

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote>
#         <strong>MODEL FEATURES IMPORTANCE COEFFICIENT</strong>
#     </blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>To understand the learning process of the model by observing the feature importance coefficients and to explain the decisions of the model.</li>
#     </ul>
# </div>

# %%
def plot_importance_coef(model, features, num=len(X.columns), save=False):
    if hasattr(model, 'coef_'): # to check coef
        importance = pd.DataFrame({
            'Value': model.coef_[0],
            'Feature': features.columns})
        plt.figure(figsize=(10, 10)) #plot
        sns.set(font_scale=1)
        sns.barplot(x='Value', y='Feature', data=importance.sort_values(by='Value', ascending=False)[0:num], 
                    palette='magma')
        plt.title('Feature Importances')
        plt.tight_layout()
        plt.show()
        if save:
            plt.savefig('importances.png')
    else:
        print("Model does not have attribute 'coef_'")

# %%
plot_importance_coef(lr_final_model, X)

# %% [markdown]
# <div style='background-color: #eee8aa; padding: 10px; display: inline-block; width: auto;'>
#     <blockquote>
#         <strong>MODEL PREDICTION</strong>
#     </blockquote>
# </div>
#
# <div style='background-color: #ffefd5; padding: 10px; color: black;'>
#     <ul>
#         <li>Making predictions with the model by selecting a random sample.</li>
#     </ul>
# </div>

# %%
random_value = X.sample(1,random_state = 35)
random_value
# Out:
#       Gender  Partner  Dependents  Tenure  PhoneService  PaperlessBilling  MonthlyCharges  TotalCharges  NEW_TotalServices  NEW_AVG_Charges  NEW_Increase  \
# 6178       0        1           0   0.878             1                 1          -1.527        -0.555                  1           -1.303         0.577
#
#       NEW_AVG_Service_Fee  MultipleLines_No phone service  MultipleLines_Yes  InternetService_Fiber optic  InternetService_No  OnlineSecurity_No internet service  \
# 6178               -1.100                           False              False                        False                True                                True
#
#       OnlineSecurity_Yes  OnlineBackup_No internet service  OnlineBackup_Yes  DeviceProtection_No internet service  DeviceProtection_Yes  \
# 6178               False                              True             False                                  True                 False
#
# ...

# %%
prediction = lr_final_model.predict(random_value)
prediction
# Out:
# array([0])
